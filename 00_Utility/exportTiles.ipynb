# %%
# import geemap
import ee

# ee.Authenticate()
ee.Initialize()

# %% [markdown]
# # Leafmap for bbox

# %%
import leafmap

# %%
m = leafmap.Map(center=[16.983124, 95.449798], zoom=15)
m.add_basemap("SATELLITE")
m
# Out:
# Map(center=[16.983124, 95.449798], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title',…

# %%
if m.user_roi_bounds() is not None:
    bbox = m.user_roi_bounds()
else:
    bbox = [95.508, 16.9859, 95.513, 16.99]

# %%
bbox
# Out:
# [95.508, 16.9859, 95.513, 16.99]

# %% [markdown]
# # ESRI

# %%
# ## ESRI Source
# from getData import tms_to_geotiff
# from PIL import Image
# import numpy as np

# # # Single image 
# # from getData import tms_to_geotiff
# # from PIL import Image
# # import numpy as np

# # nr = 1
# # image = "D:/SIG/Pantanaw/Test_image/test_source_image/esri_imagery_test01.tif" 
# # satImg = tms_to_geotiff(output=image, bbox=bbox, zoom=19, source="ESRI", overwrite=True, return_image=True)

# zoom_levels = range(15, 20)
# output_dir = "D:/SIG/Pantanaw/Test_image/test_source_image/"
# base_filename = "esri_imagery_test"
# for zoom in zoom_levels:
#     output_file = f"{output_dir}{base_filename}_z{zoom}.tif"
#     try:
#         print(f"Downloading zoom level {zoom} to {output_file}...")
#         satImg = tms_to_geotiff(
#             output=output_file, 
#             bbox=bbox, 
#             zoom=zoom, 
#             source="ESRI", 
#             overwrite=True, 
#             return_image=True
#         )
#         print(f"Zoom level {zoom} downloaded successfully.")
#     except Exception as e:
#         print(f"Failed to download zoom level {zoom}: {e}")

# %% [markdown]
# # BING

# %%
bbox
# Out:
# [95.508, 16.9859, 95.513, 16.99]

# %%
from getData import tms_to_geotiff
import numpy as np
import math
import os

import rasterio
from rasterio.merge import merge
from rasterio.transform import from_bounds

def tile_to_lon_lat(x, y, zoom):
    """Convert tile (x, y) at a specified zoom level to longitude and latitude."""
    n = 2 ** zoom
    lon_deg = x / n * 360.0 - 180.0
    lat_rad = math.atan(math.sinh(math.pi * (1 - 2 * y / n)))
    lat_deg = math.degrees(lat_rad)
    return lon_deg, lat_deg

def lon_lat_to_tile(lon, lat, zoom):
    """Convert latitude and longitude to tile (x, y) at a specified zoom level."""
    n = 2 ** zoom
    x = int((lon + 180.0) / 360.0 * n)
    y = int(
        (1.0 - (math.log(math.tan(math.radians(lat)) + 1 / math.cos(math.radians(lat))) / math.pi)) / 2.0 * n
    )
    return x, y

def tile_to_quadkey(x, y, zoom):
    """Generate the quadkey for a given tile (x, y) at zoom level."""
    quadkey = []
    for i in range(zoom, 0, -1):
        digit = 0
        mask = 1 << (i - 1)
        if (x & mask) != 0:
            digit += 1
        if (y & mask) != 0:
            digit += 2
        quadkey.append(str(digit))
    return ''.join(quadkey)

# Set parameters
bbox = [95.508, 16.9859, 95.513, 16.99]  # [min_lon, min_lat, max_lon, max_lat]
zoom = 19
tiles_dir = "D:/SIG/Pantanaw/Test_image/test_source_image/bing/temp"
base_filename = "bing_tile"

# Create output directory if it doesn't exist
os.makedirs(tiles_dir, exist_ok=True)

# Calculate tile ranges for the bounding box
x_min, y_min = lon_lat_to_tile(bbox[0], bbox[1], zoom)
x_max, y_max = lon_lat_to_tile(bbox[2], bbox[3], zoom)

# Ensure y_min < y_max for looping
if y_min > y_max:
    y_min, y_max = y_max, y_min

# Loop over each tile within the bounding box
for x in range(x_min, x_max + 1):
    for y in range(y_min, y_max + 1):
        # Generate the quadkey for the current tile
        quadkey = tile_to_quadkey(x, y, zoom)
        
        # Calculate the bounding box for the current tile
        lon_min, lat_max = tile_to_lon_lat(x, y, zoom)
        lon_max, lat_min = tile_to_lon_lat(x + 1, y + 1, zoom)
        tile_bbox = [lon_min, lat_min, lon_max, lat_max]
        
        # Define the output filename
        output_file = f"{tiles_dir}{base_filename}_z{zoom}_x{x}_y{y}.tif"
        
        # Create the Bing tile URL
        bing_url = f"https://t0.tiles.virtualearth.net/tiles/a{quadkey}.jpeg?g=685&mkt=en-us&n=z"
        
        # Print debugging info
        print(f"Downloading tile: x={x}, y={y}, zoom={zoom}, quadkey={quadkey}")
        print(f"BBox: {tile_bbox}")
        print(f"Output file: {output_file}")

        # Attempt to download the tile
        try:
            tms_to_geotiff(
                output=output_file,
                bbox=tile_bbox,  # Pass the calculated BBox for the tile
                zoom=zoom,
                source=bing_url,  # Pass the full Bing URL as the source
                overwrite=True,
                return_image=False
            )
            print(f"Tile x={x}, y={y} downloaded successfully.")
        except Exception as e:
            print(f"Failed to download tile x={x}, y={y}: {e}")

print("Download process completed.")

# Directory containing the downloaded tiles
# tiles_dir = "D:/SIG/Pantanaw/Test_image/test_source_image/bing/"

# Output file path for the merged GeoTIFF
output_file = "D:/SIG/Pantanaw/Test_image/test_source_image/bing/merged_bing_image.tif"

# Find all .tif files in the directory
tile_files = [
    os.path.join(tiles_dir, f)
    for f in os.listdir(tiles_dir)
    if f.endswith(".tif")
]

# Check if any tiles are found
if not tile_files:
    print("No tile files found. Please make sure tiles are downloaded.")
    exit()

# Open all tile files with rasterio
sources = [rasterio.open(tile) for tile in tile_files]

# Merge tiles
print("Merging tiles...")
mosaic, out_transform = merge(sources)

# Get metadata from the first tile
out_meta = sources[0].meta.copy()

# Update metadata for the merged dataset
out_meta.update({
    "driver": "GTiff",
    "height": mosaic.shape[1],
    "width": mosaic.shape[2],
    "transform": out_transform,
    "crs": sources[0].crs
})

# Write the merged GeoTIFF
print(f"Writing merged GeoTIFF to {output_file}...")
with rasterio.open(output_file, "w", **out_meta) as dest:
    dest.write(mosaic)

print("Merging completed!")

# Close all opened tile files
for src in sources:
    src.close()
# Out:
# Downloading tile: x=401237, y=237029, zoom=19, quadkey=1322003331323210303
# BBox: [95.50758361816406, 16.98981542605184, 95.50827026367188, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237029.tif
# Tile x=401237, y=237029 downloaded successfully.
# Downloading tile: x=401237, y=237030, zoom=19, quadkey=1322003331323210321
# BBox: [95.50758361816406, 16.98915874686246, 95.50827026367188, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237030.tif
# Tile x=401237, y=237030 downloaded successfully.
# Downloading tile: x=401237, y=237031, zoom=19, quadkey=1322003331323210323
# BBox: [95.50758361816406, 16.9885020653736, 95.50827026367188, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237031.tif
# Tile x=401237, y=237031 downloaded successfully.
# Downloading tile: x=401237, y=237032, zoom=19, quadkey=1322003331323212101
# BBox: [95.50758361816406, 16.98784538158533, 95.50827026367188, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237032.tif
# Tile x=401237, y=237032 downloaded successfully.
# Downloading tile: x=401237, y=237033, zoom=19, quadkey=1322003331323212103
# BBox: [95.50758361816406, 16.987188695497736, 95.50827026367188, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237033.tif
# Tile x=401237, y=237033 downloaded successfully.
# Downloading tile: x=401237, y=237034, zoom=19, quadkey=1322003331323212121
# BBox: [95.50758361816406, 16.98653200711089, 95.50827026367188, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237034.tif
# Tile x=401237, y=237034 downloaded successfully.
# Downloading tile: x=401237, y=237035, zoom=19, quadkey=1322003331323212123
# BBox: [95.50758361816406, 16.985875316424874, 95.50827026367188, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401237_y237035.tif
# Tile x=401237, y=237035 downloaded successfully.
# Downloading tile: x=401238, y=237029, zoom=19, quadkey=1322003331323210312
# BBox: [95.50827026367188, 16.98981542605184, 95.50895690917969, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237029.tif
# Tile x=401238, y=237029 downloaded successfully.
# Downloading tile: x=401238, y=237030, zoom=19, quadkey=1322003331323210330
# BBox: [95.50827026367188, 16.98915874686246, 95.50895690917969, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237030.tif
# Tile x=401238, y=237030 downloaded successfully.
# Downloading tile: x=401238, y=237031, zoom=19, quadkey=1322003331323210332
# BBox: [95.50827026367188, 16.9885020653736, 95.50895690917969, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237031.tif
# Tile x=401238, y=237031 downloaded successfully.
# Downloading tile: x=401238, y=237032, zoom=19, quadkey=1322003331323212110
# BBox: [95.50827026367188, 16.98784538158533, 95.50895690917969, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237032.tif
# Tile x=401238, y=237032 downloaded successfully.
# Downloading tile: x=401238, y=237033, zoom=19, quadkey=1322003331323212112
# BBox: [95.50827026367188, 16.987188695497736, 95.50895690917969, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237033.tif
# Tile x=401238, y=237033 downloaded successfully.
# Downloading tile: x=401238, y=237034, zoom=19, quadkey=1322003331323212130
# BBox: [95.50827026367188, 16.98653200711089, 95.50895690917969, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237034.tif
# Tile x=401238, y=237034 downloaded successfully.
# Downloading tile: x=401238, y=237035, zoom=19, quadkey=1322003331323212132
# BBox: [95.50827026367188, 16.985875316424874, 95.50895690917969, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401238_y237035.tif
# Tile x=401238, y=237035 downloaded successfully.
# Downloading tile: x=401239, y=237029, zoom=19, quadkey=1322003331323210313
# BBox: [95.50895690917969, 16.98981542605184, 95.5096435546875, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237029.tif
# Tile x=401239, y=237029 downloaded successfully.
# Downloading tile: x=401239, y=237030, zoom=19, quadkey=1322003331323210331
# BBox: [95.50895690917969, 16.98915874686246, 95.5096435546875, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237030.tif
# Tile x=401239, y=237030 downloaded successfully.
# Downloading tile: x=401239, y=237031, zoom=19, quadkey=1322003331323210333
# BBox: [95.50895690917969, 16.9885020653736, 95.5096435546875, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237031.tif
# Tile x=401239, y=237031 downloaded successfully.
# Downloading tile: x=401239, y=237032, zoom=19, quadkey=1322003331323212111
# BBox: [95.50895690917969, 16.98784538158533, 95.5096435546875, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237032.tif
# Tile x=401239, y=237032 downloaded successfully.
# Downloading tile: x=401239, y=237033, zoom=19, quadkey=1322003331323212113
# BBox: [95.50895690917969, 16.987188695497736, 95.5096435546875, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237033.tif
# Tile x=401239, y=237033 downloaded successfully.
# Downloading tile: x=401239, y=237034, zoom=19, quadkey=1322003331323212131
# BBox: [95.50895690917969, 16.98653200711089, 95.5096435546875, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237034.tif
# Tile x=401239, y=237034 downloaded successfully.
# Downloading tile: x=401239, y=237035, zoom=19, quadkey=1322003331323212133
# BBox: [95.50895690917969, 16.985875316424874, 95.5096435546875, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401239_y237035.tif
# Tile x=401239, y=237035 downloaded successfully.
# Downloading tile: x=401240, y=237029, zoom=19, quadkey=1322003331323211202
# BBox: [95.5096435546875, 16.98981542605184, 95.51033020019531, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237029.tif
# Tile x=401240, y=237029 downloaded successfully.
# Downloading tile: x=401240, y=237030, zoom=19, quadkey=1322003331323211220
# BBox: [95.5096435546875, 16.98915874686246, 95.51033020019531, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237030.tif
# Tile x=401240, y=237030 downloaded successfully.
# Downloading tile: x=401240, y=237031, zoom=19, quadkey=1322003331323211222
# BBox: [95.5096435546875, 16.9885020653736, 95.51033020019531, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237031.tif
# Tile x=401240, y=237031 downloaded successfully.
# Downloading tile: x=401240, y=237032, zoom=19, quadkey=1322003331323213000
# BBox: [95.5096435546875, 16.98784538158533, 95.51033020019531, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237032.tif
# Tile x=401240, y=237032 downloaded successfully.
# Downloading tile: x=401240, y=237033, zoom=19, quadkey=1322003331323213002
# BBox: [95.5096435546875, 16.987188695497736, 95.51033020019531, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237033.tif
# Tile x=401240, y=237033 downloaded successfully.
# Downloading tile: x=401240, y=237034, zoom=19, quadkey=1322003331323213020
# BBox: [95.5096435546875, 16.98653200711089, 95.51033020019531, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237034.tif
# Tile x=401240, y=237034 downloaded successfully.
# Downloading tile: x=401240, y=237035, zoom=19, quadkey=1322003331323213022
# BBox: [95.5096435546875, 16.985875316424874, 95.51033020019531, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401240_y237035.tif
# Tile x=401240, y=237035 downloaded successfully.
# Downloading tile: x=401241, y=237029, zoom=19, quadkey=1322003331323211203
# BBox: [95.51033020019531, 16.98981542605184, 95.51101684570312, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237029.tif
# Tile x=401241, y=237029 downloaded successfully.
# Downloading tile: x=401241, y=237030, zoom=19, quadkey=1322003331323211221
# BBox: [95.51033020019531, 16.98915874686246, 95.51101684570312, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237030.tif
# Tile x=401241, y=237030 downloaded successfully.
# Downloading tile: x=401241, y=237031, zoom=19, quadkey=1322003331323211223
# BBox: [95.51033020019531, 16.9885020653736, 95.51101684570312, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237031.tif
# Tile x=401241, y=237031 downloaded successfully.
# Downloading tile: x=401241, y=237032, zoom=19, quadkey=1322003331323213001
# BBox: [95.51033020019531, 16.98784538158533, 95.51101684570312, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237032.tif
# Tile x=401241, y=237032 downloaded successfully.
# Downloading tile: x=401241, y=237033, zoom=19, quadkey=1322003331323213003
# BBox: [95.51033020019531, 16.987188695497736, 95.51101684570312, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237033.tif
# Tile x=401241, y=237033 downloaded successfully.
# Downloading tile: x=401241, y=237034, zoom=19, quadkey=1322003331323213021
# BBox: [95.51033020019531, 16.98653200711089, 95.51101684570312, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237034.tif
# Tile x=401241, y=237034 downloaded successfully.
# Downloading tile: x=401241, y=237035, zoom=19, quadkey=1322003331323213023
# BBox: [95.51033020019531, 16.985875316424874, 95.51101684570312, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401241_y237035.tif
# Tile x=401241, y=237035 downloaded successfully.
# Downloading tile: x=401242, y=237029, zoom=19, quadkey=1322003331323211212
# BBox: [95.51101684570312, 16.98981542605184, 95.51170349121094, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237029.tif
# Tile x=401242, y=237029 downloaded successfully.
# Downloading tile: x=401242, y=237030, zoom=19, quadkey=1322003331323211230
# BBox: [95.51101684570312, 16.98915874686246, 95.51170349121094, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237030.tif
# Tile x=401242, y=237030 downloaded successfully.
# Downloading tile: x=401242, y=237031, zoom=19, quadkey=1322003331323211232
# BBox: [95.51101684570312, 16.9885020653736, 95.51170349121094, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237031.tif
# Tile x=401242, y=237031 downloaded successfully.
# Downloading tile: x=401242, y=237032, zoom=19, quadkey=1322003331323213010
# BBox: [95.51101684570312, 16.98784538158533, 95.51170349121094, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237032.tif
# Tile x=401242, y=237032 downloaded successfully.
# Downloading tile: x=401242, y=237033, zoom=19, quadkey=1322003331323213012
# BBox: [95.51101684570312, 16.987188695497736, 95.51170349121094, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237033.tif
# Tile x=401242, y=237033 downloaded successfully.
# Downloading tile: x=401242, y=237034, zoom=19, quadkey=1322003331323213030
# BBox: [95.51101684570312, 16.98653200711089, 95.51170349121094, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237034.tif
# Tile x=401242, y=237034 downloaded successfully.
# Downloading tile: x=401242, y=237035, zoom=19, quadkey=1322003331323213032
# BBox: [95.51101684570312, 16.985875316424874, 95.51170349121094, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401242_y237035.tif
# Tile x=401242, y=237035 downloaded successfully.
# Downloading tile: x=401243, y=237029, zoom=19, quadkey=1322003331323211213
# BBox: [95.51170349121094, 16.98981542605184, 95.51239013671875, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237029.tif
# Tile x=401243, y=237029 downloaded successfully.
# Downloading tile: x=401243, y=237030, zoom=19, quadkey=1322003331323211231
# BBox: [95.51170349121094, 16.98915874686246, 95.51239013671875, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237030.tif
# Tile x=401243, y=237030 downloaded successfully.
# Downloading tile: x=401243, y=237031, zoom=19, quadkey=1322003331323211233
# BBox: [95.51170349121094, 16.9885020653736, 95.51239013671875, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237031.tif
# Tile x=401243, y=237031 downloaded successfully.
# Downloading tile: x=401243, y=237032, zoom=19, quadkey=1322003331323213011
# BBox: [95.51170349121094, 16.98784538158533, 95.51239013671875, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237032.tif
# Tile x=401243, y=237032 downloaded successfully.
# Downloading tile: x=401243, y=237033, zoom=19, quadkey=1322003331323213013
# BBox: [95.51170349121094, 16.987188695497736, 95.51239013671875, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237033.tif
# Tile x=401243, y=237033 downloaded successfully.
# Downloading tile: x=401243, y=237034, zoom=19, quadkey=1322003331323213031
# BBox: [95.51170349121094, 16.98653200711089, 95.51239013671875, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237034.tif
# Tile x=401243, y=237034 downloaded successfully.
# Downloading tile: x=401243, y=237035, zoom=19, quadkey=1322003331323213033
# BBox: [95.51170349121094, 16.985875316424874, 95.51239013671875, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401243_y237035.tif
# Tile x=401243, y=237035 downloaded successfully.
# Downloading tile: x=401244, y=237029, zoom=19, quadkey=1322003331323211302
# BBox: [95.51239013671875, 16.98981542605184, 95.51307678222656, 16.990472102941652]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237029.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237029.tif
# Tile x=401244, y=237029 downloaded successfully.
# Downloading tile: x=401244, y=237030, zoom=19, quadkey=1322003331323211320
# BBox: [95.51239013671875, 16.98915874686246, 95.51307678222656, 16.98981542605184]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237030.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237030.tif
# Tile x=401244, y=237030 downloaded successfully.
# Downloading tile: x=401244, y=237031, zoom=19, quadkey=1322003331323211322
# BBox: [95.51239013671875, 16.9885020653736, 95.51307678222656, 16.98915874686246]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237031.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237031.tif
# Tile x=401244, y=237031 downloaded successfully.
# Downloading tile: x=401244, y=237032, zoom=19, quadkey=1322003331323213100
# BBox: [95.51239013671875, 16.98784538158533, 95.51307678222656, 16.9885020653736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237032.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237032.tif
# Tile x=401244, y=237032 downloaded successfully.
# Downloading tile: x=401244, y=237033, zoom=19, quadkey=1322003331323213102
# BBox: [95.51239013671875, 16.987188695497736, 95.51307678222656, 16.98784538158533]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237033.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237033.tif
# Tile x=401244, y=237033 downloaded successfully.
# Downloading tile: x=401244, y=237034, zoom=19, quadkey=1322003331323213120
# BBox: [95.51239013671875, 16.98653200711089, 95.51307678222656, 16.987188695497736]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237034.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237034.tif
# Tile x=401244, y=237034 downloaded successfully.
# Downloading tile: x=401244, y=237035, zoom=19, quadkey=1322003331323213122
# BBox: [95.51239013671875, 16.985875316424874, 95.51307678222656, 16.98653200711089]
# Output file: D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237035.tif
# Downloaded image 1/1
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Pantanaw/Test_image/test_source_image/bing/tempbing_tile_z19_x401244_y237035.tif
# Tile x=401244, y=237035 downloaded successfully.
# Download process completed.
# No tile files found. Please make sure tiles are downloaded.
# Merging tiles...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 118
#     116 # Merge tiles
#     117 print("Merging tiles...")
# --> 118 mosaic, out_transform = merge(sources)
#     120 # Get metadata from the first tile
#     121 out_meta = sources[0].meta.copy()
#
# File c:\Users\molec\miniconda3\Lib\site-packages\rasterio\merge.py:208, in merge(datasets, bounds, res, nodata, dtype, precision, indexes, output_count, resampling, method, target_aligned_pixels, dst_path, dst_kwds)
#     204     raise ValueError('Unknown method {0}, must be one of {1} or callable'
#     205                      .format(method, list(MERGE_METHODS.keys())))
#     207 # Create a dataset_opener object to use in several places in this function.
# --> 208 if isinstance(datasets[0], (str, os.PathLike)):
#     209     dataset_opener = rasterio.open
#     210 else:
#
# IndexError: list index out of range
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Auto1 Download from GEE Asset

# %%
# import os
# from getData import tms_to_geotiff
# from PIL import Image
# import numpy as np
# areas_list = [
#     "0_vietnam_areas_shp", "10_cambodia_areas_shp", "11_cambodia_areas_shp", "12_cambodia_areas_shp",
#     "13_cambodia_areas_shp", "14_cambodia_areas_shp", "15_cambodia_areas_shp", "16_cambodia_areas_shp",
#     "17_cambodia_areas_shp", "18_cambodia_areas_shp", "19_cambodia_areas_shp", "1_vietnam_areas_shp",
#     "20_cambodia_areas_shp", "21_cambodia_areas_shp", "22_vietnam_areas_shp", "23_vietnam_areas_shp",
#     "24_vietnam_areas_shp", "25_vietnam_areas_shp", "26_vietnam_areas_shp", "27_vietnam_areas_shp",
#     "28_vietnam_areas_shp", "29_vietnam_areas_shp", "2_cambodia_areas_shp", "30_vietnam_areas_shp",
#     "31_vietnam_areas_shp", "32_vietnam_areas_shp", "33_cambodia_areas_shp", "34_cambodia_areas_shp",
#     "35_cambodia_areas_shp", "36_cambodia_areas_shp", "37_cambodia_areas_shp", "38_cambodia_areas_shp",
#     "39_cambodia_areas_shp", "3_cambodia_areas_shp", "40_vietnam_areas_shp", "41_vietnam_areas_shp",
#     "42_vietnam_areas_shp", "43_vietnam_areas_shp", "44_vietnam_areas_shp", "45_vietnam_areas_shp",
#     "46_vietnam_areas_shp", "47_vietnam_areas_shp", "48_vietnam_areas_shp", "49_vietnam_areas_shp",
#     "4_cambodia_areas_shp", "50_vietnam_areas_shp", "51_vietnam_areas_shp", "52_vietnam_areas_shp",
#     "53_vietnam_areas_shp", "54_vietnam_areas_shp", "55_vietnam_areas_shp", "56_vietnam_areas_shp",
#     "57_cambodia_areas_shp", "58_cambodia_areas_shp", "59_cambodia_areas_shp", "5_cambodia_areas_shp",
#     "60_cambodia_areas_shp", "61_cambodia_areas_shp", "6_cambodia_areas_shp", "7_cambodia_areas_shp",
#     "8_cambodia_areas_shp", "9_cambodia_areas_shp"
# ]
# for name in areas_list:
    
#     cambodia_areas = ee.FeatureCollection(f'projects/earthengine-legacy/assets/projects/servir-mekong/khProject/data/{name}')
    
    
#     bounds_info = cambodia_areas.geometry().bounds().getInfo()

    
#     coordinates = bounds_info['coordinates'][0]

    
#     longitudes = [point[0] for point in coordinates]
#     latitudes = [point[1] for point in coordinates]

#     xmin = min(longitudes)
#     xmax = max(longitudes)
#     ymin = min(latitudes)
#     ymax = max(latitudes)

#     print(f"Processing {name}...")
#     print(f"xmin: {xmin}, xmax: {xmax}, ymin: {ymin}, ymax: {ymax}")

    
#     bbox = [xmin, ymin, xmax, ymax]
#     output_image = f"D:/SIG/Sam2_soucre/Crops/imagesZ19/{name}_z19.tif"

#     # Check if the image already exists before downloading
#     if os.path.exists(output_image):
#         print(f"Image for {name} already exists. Skipping download.")
#     else:
#         # Download the image only if it doesn't already exist
#         satImg = tms_to_geotiff(output=output_image, bbox=bbox, zoom=19, source="Satellite", overwrite=True, return_image=True)
#         print(f"Image for {name} saved at {output_image}")

# print("All areas processed.")

# %%
# import csv
# import os
# from getData import tms_to_geotiff
# import ee

# # Authenticate and initialize the Earth Engine API
# ee.Initialize()

# areas_list = [
#     "0_vietnam_areas_shp", "10_cambodia_areas_shp", "11_cambodia_areas_shp", "12_cambodia_areas_shp",
#     "13_cambodia_areas_shp", "14_cambodia_areas_shp", "15_cambodia_areas_shp", "16_cambodia_areas_shp",
#     "17_cambodia_areas_shp", "18_cambodia_areas_shp", "19_cambodia_areas_shp", "1_vietnam_areas_shp",
#     "20_cambodia_areas_shp", "21_cambodia_areas_shp", "22_vietnam_areas_shp", "23_vietnam_areas_shp",
#     "24_vietnam_areas_shp", "25_vietnam_areas_shp", "26_vietnam_areas_shp", "27_vietnam_areas_shp",
#     "28_vietnam_areas_shp", "29_vietnam_areas_shp", "2_cambodia_areas_shp", "30_vietnam_areas_shp",
#     "31_vietnam_areas_shp", "32_vietnam_areas_shp", "33_cambodia_areas_shp", "34_cambodia_areas_shp",
#     "35_cambodia_areas_shp", "36_cambodia_areas_shp", "37_cambodia_areas_shp", "38_cambodia_areas_shp",
#     "39_cambodia_areas_shp", "3_cambodia_areas_shp", "40_vietnam_areas_shp", "41_vietnam_areas_shp",
#     "42_vietnam_areas_shp", "43_vietnam_areas_shp", "44_vietnam_areas_shp", "45_vietnam_areas_shp",
#     "46_vietnam_areas_shp", "47_vietnam_areas_shp", "48_vietnam_areas_shp", "49_vietnam_areas_shp",
#     "4_cambodia_areas_shp", "50_vietnam_areas_shp", "51_vietnam_areas_shp", "52_vietnam_areas_shp",
#     "53_vietnam_areas_shp", "54_vietnam_areas_shp", "55_vietnam_areas_shp", "56_vietnam_areas_shp",
#     "57_cambodia_areas_shp", "58_cambodia_areas_shp", "59_cambodia_areas_shp", "5_cambodia_areas_shp",
#     "60_cambodia_areas_shp", "61_cambodia_areas_shp", "6_cambodia_areas_shp", "7_cambodia_areas_shp",
#     "8_cambodia_areas_shp", "9_cambodia_areas_shp"
# ]

# output_csv = "D:/SIG/Sam2_soucre/Crops/bounding_boxes.csv"
# with open(output_csv, mode='w', newline='') as file:
#     writer = csv.writer(file)
#     # Write headers for CSV file
#     writer.writerow(["Area", "xmin", "xmax", "ymin", "ymax"])

#     for name in areas_list:
#         # Fetch feature collection
#         cambodia_areas = ee.FeatureCollection(f'projects/earthengine-legacy/assets/projects/servir-mekong/khProject/data/{name}')
#         bounds_info = cambodia_areas.geometry().bounds().getInfo()
#         coordinates = bounds_info['coordinates'][0]

#         # Calculate bounding box coordinates 
#         ## Important Part
#         longitudes = [point[0] for point in coordinates]
#         latitudes = [point[1] for point in coordinates]
#         xmin = min(longitudes)
#         xmax = max(longitudes)
#         ymin = min(latitudes)
#         ymax = max(latitudes)

#         # Print and log bounding box information
#         print(f"Processing {name} - xmin: {xmin}, xmax: {xmax}, ymin: {ymin}, ymax: {ymax}")
#         writer.writerow([name, xmin, xmax, ymin, ymax])

# print(f"Bounding box data saved to {output_csv}.")

# %% [markdown]
# # Auto2 Download from GEE Asset

# %%
import os
import pandas as pd
from getData import tms_to_geotiff
from PIL import Image
import numpy as np

input_csv = "D:/SIG/Sam2_soucre/Crops/bounding_boxes.csv"
output= "D:/SIG/Sam2_soucre/Crops/imagesZ19/"
os.makedirs(output, exist_ok=True)

df = pd.read_csv(input_csv)
df.head(5)

for index, row in df.iterrows():
    name = row['Area']
    xmin = row['xmin']
    xmax = row['xmax']
    ymin = row['ymin']
    ymax = row['ymax']

    print(f"Processing {name}...")
    print(f"xmin: {xmin}, xmax: {xmax}, ymin: {ymin}, ymax: {ymax}")

    bbox = [xmin, ymin, xmax, ymax]
    output_image = os.path.join(output, f"{name}_z20.tif")

    
    if os.path.exists(output_image):
        print(f"Image for {name} already exists. Skipping download.")
    else:
        satImg = tms_to_geotiff(output=output_image, bbox=bbox, zoom=19, source="Satellite", overwrite=True, return_image=True)
        print(f"Image for {name} saved at {output_image}")

print("All areas processed.")

# %%
import ee
import rasterio
# Initialize Earth Engine
ee.Initialize()

areas_list = [
    "0_vietnam_areas_shp", "10_cambodia_areas_shp", "11_cambodia_areas_shp", "12_cambodia_areas_shp",
    "13_cambodia_areas_shp", "14_cambodia_areas_shp", "15_cambodia_areas_shp", "16_cambodia_areas_shp",
    "17_cambodia_areas_shp", "18_cambodia_areas_shp", "19_cambodia_areas_shp", "1_vietnam_areas_shp",
    "20_cambodia_areas_shp", "21_cambodia_areas_shp", "22_vietnam_areas_shp", "23_vietnam_areas_shp",
    "24_vietnam_areas_shp", "25_vietnam_areas_shp", "26_vietnam_areas_shp", "27_vietnam_areas_shp",
    "28_vietnam_areas_shp", "29_vietnam_areas_shp", "2_cambodia_areas_shp", "30_vietnam_areas_shp",
    "31_vietnam_areas_shp", "32_vietnam_areas_shp", "33_cambodia_areas_shp", "34_cambodia_areas_shp",
    "35_cambodia_areas_shp", "36_cambodia_areas_shp", "37_cambodia_areas_shp", "38_cambodia_areas_shp",
    "39_cambodia_areas_shp", "3_cambodia_areas_shp", "40_vietnam_areas_shp", "41_vietnam_areas_shp",
    "42_vietnam_areas_shp", "43_vietnam_areas_shp", "44_vietnam_areas_shp", "45_vietnam_areas_shp",
    "46_vietnam_areas_shp", "47_vietnam_areas_shp", "48_vietnam_areas_shp", "49_vietnam_areas_shp",
    "4_cambodia_areas_shp", "50_vietnam_areas_shp", "51_vietnam_areas_shp", "52_vietnam_areas_shp",
    "53_vietnam_areas_shp", "54_vietnam_areas_shp", "55_vietnam_areas_shp", "56_vietnam_areas_shp",
    "57_cambodia_areas_shp", "58_cambodia_areas_shp", "59_cambodia_areas_shp", "5_cambodia_areas_shp",
    "60_cambodia_areas_shp", "61_cambodia_areas_shp", "6_cambodia_areas_shp", "7_cambodia_areas_shp",
    "8_cambodia_areas_shp", "9_cambodia_areas_shp"
]

for name in areas_list:
    
    cambodia_areas = ee.FeatureCollection(f'projects/earthengine-legacy/assets/projects/servir-mekong/khProject/data/{name}')
    

    with rasterio.open(f"D:/SIG/Sam2_soucre/Crops/imagesZ19/{name}.tif") as dataset:
        width = dataset.width
        height = dataset.height
    
    print(f"Width: {width}, Height: {height}")

    
    def normalizedDistanceImages(feature):
        
        rasterizedPolygon = ee.Image.constant(0).clip(feature.geometry()).unmask(1, False)
        distance = rasterizedPolygon.distance(kernel=ee.Kernel.euclidean(255), skipMasked=False).clip(feature.geometry()).rename("distance")

        maxDistanceImage = distance.reduceRegion(
            reducer=ee.Reducer.max(),
            geometry=feature.geometry(),
            scale=0.5,
            maxPixels=1e9
        ).get('distance')

        normalizedDistance = distance.divide(ee.Number(maxDistanceImage))
        return normalizedDistance.clip(feature.geometry()).set('system:index', ee.String(feature.get('id')))

    
    normalizedDistanceImages = cambodia_areas.map(normalizedDistanceImages)
    finalNormalizedDistanceImage = ee.ImageCollection(normalizedDistanceImages).mosaic()
    print(f"Band Names: {finalNormalizedDistanceImage.bandNames().getInfo()}")
    dimensions = f"{width}x{height}"

    
    export_task = ee.batch.Export.image.toDrive(
        image=finalNormalizedDistanceImage,
        description=f"Export_Normalized_Distance_{name}",
        folder="FieldZ19",  
        fileNamePrefix=f"{name}_fields",  
        dimensions=dimensions,  
        region=cambodia_areas.geometry().bounds(),  
        scale=None,  
        crs="EPSG:4326",  
        maxPixels=1e12  
    )

    export_task.start()
    print(f"Export task started for {name}!")
# Out:
# Width: 26299, Height: 28036
# Band Names: ['distance']
# Export task started for 0_vietnam_areas_shp!
# Width: 17225, Height: 17321
# Band Names: ['distance']
# Export task started for 10_cambodia_areas_shp!
# Width: 17114, Height: 17218
# Band Names: ['distance']
# Export task started for 11_cambodia_areas_shp!
# Width: 17114, Height: 17310
# Band Names: ['distance']
# Export task started for 12_cambodia_areas_shp!
# Width: 17115, Height: 17243
# Band Names: ['distance']
# Export task started for 13_cambodia_areas_shp!
# Width: 17115, Height: 17401
# Band Names: ['distance']
# Export task started for 14_cambodia_areas_shp!
# Width: 17115, Height: 17213
# Band Names: ['distance']
# Export task started for 15_cambodia_areas_shp!
# Width: 17113, Height: 17256
# Band Names: ['distance']
# Export task started for 16_cambodia_areas_shp!
# Width: 17118, Height: 17228
# Band Names: ['distance']
# Export task started for 17_cambodia_areas_shp!
# Width: 17113, Height: 17322
# Band Names: ['distance']
# Export task started for 18_cambodia_areas_shp!
# Width: 17114, Height: 17390
# Band Names: ['distance']
# Export task started for 19_cambodia_areas_shp!
# Width: 26488, Height: 28045
# Band Names: ['distance']
# Export task started for 1_vietnam_areas_shp!
# Width: 17092, Height: 17231
# Band Names: ['distance']
# Export task started for 20_cambodia_areas_shp!
# Width: 17116, Height: 17363
# Band Names: ['distance']
# Export task started for 21_cambodia_areas_shp!
# Width: 17278, Height: 18016
# Band Names: ['distance']
# Export task started for 22_vietnam_areas_shp!
# Width: 17271, Height: 17919
# Band Names: ['distance']
# Export task started for 23_vietnam_areas_shp!
# Width: 17273, Height: 18045
# Band Names: ['distance']
# Export task started for 24_vietnam_areas_shp!
# Width: 17260, Height: 17973
# Band Names: ['distance']
# Export task started for 25_vietnam_areas_shp!
# Width: 17259, Height: 17991
# Band Names: ['distance']
# Export task started for 26_vietnam_areas_shp!
# Width: 17043, Height: 18076
# Band Names: ['distance']
# Export task started for 27_vietnam_areas_shp!
# Width: 17268, Height: 18086
# Band Names: ['distance']
# Export task started for 28_vietnam_areas_shp!
# Width: 17301, Height: 18169
# Band Names: ['distance']
# Export task started for 29_vietnam_areas_shp!
# Width: 17080, Height: 17165
# Band Names: ['distance']
# Export task started for 2_cambodia_areas_shp!
# Width: 17272, Height: 17953
# Band Names: ['distance']
# Export task started for 30_vietnam_areas_shp!
# Width: 17274, Height: 18007
# Band Names: ['distance']
# Export task started for 31_vietnam_areas_shp!
# Width: 17273, Height: 17926
# Band Names: ['distance']
# Export task started for 32_vietnam_areas_shp!
# Width: 17298, Height: 17641
# Band Names: ['distance']
# Export task started for 33_cambodia_areas_shp!
# Width: 17189, Height: 17530
# Band Names: ['distance']
# Export task started for 34_cambodia_areas_shp!
# Width: 17153, Height: 17496
# Band Names: ['distance']
# Export task started for 35_cambodia_areas_shp!
# Width: 17189, Height: 17537
# Band Names: ['distance']
# Export task started for 36_cambodia_areas_shp!
# Width: 17264, Height: 17600
# Band Names: ['distance']
# Export task started for 37_cambodia_areas_shp!
# Width: 17299, Height: 17636
# Band Names: ['distance']
# Export task started for 38_cambodia_areas_shp!
# Width: 17278, Height: 17598
# Band Names: ['distance']
# Export task started for 39_cambodia_areas_shp!
# Width: 17114, Height: 17242
# Band Names: ['distance']
# Export task started for 3_cambodia_areas_shp!
# Width: 17430, Height: 18359
# Band Names: ['distance']
# Export task started for 40_vietnam_areas_shp!
# Width: 17727, Height: 18581
# Band Names: ['distance']
# Export task started for 41_vietnam_areas_shp!
# Width: 17430, Height: 18287
# Band Names: ['distance']
# Export task started for 42_vietnam_areas_shp!
# Width: 16992, Height: 17735
# Band Names: ['distance']
# Export task started for 43_vietnam_areas_shp!
# Width: 17430, Height: 18141
# Band Names: ['distance']
# Export task started for 44_vietnam_areas_shp!
# Width: 17430, Height: 18055
# Band Names: ['distance']
# Export task started for 45_vietnam_areas_shp!
# Width: 17430, Height: 17897
# Band Names: ['distance']
# Export task started for 46_vietnam_areas_shp!
# Width: 17540, Height: 17907
# Band Names: ['distance']
# Export task started for 47_vietnam_areas_shp!
# Width: 17430, Height: 17740
# Band Names: ['distance']
# Export task started for 48_vietnam_areas_shp!
# Width: 17430, Height: 17705
# Band Names: ['distance']
# Export task started for 49_vietnam_areas_shp!
# Width: 17115, Height: 17347
# Band Names: ['distance']
# Export task started for 4_cambodia_areas_shp!
# Width: 17526, Height: 17795
# Band Names: ['distance']
# Export task started for 50_vietnam_areas_shp!
# Width: 17430, Height: 17682
# Band Names: ['distance']
# Export task started for 51_vietnam_areas_shp!
# Width: 17391, Height: 17658
# Band Names: ['distance']
# Export task started for 52_vietnam_areas_shp!
# Width: 17414, Height: 17659
# Band Names: ['distance']
# Export task started for 53_vietnam_areas_shp!
# Width: 17430, Height: 17640
# Band Names: ['distance']
# Export task started for 54_vietnam_areas_shp!
# Width: 17430, Height: 17623
# Band Names: ['distance']
# Export task started for 55_vietnam_areas_shp!
# Width: 17406, Height: 17672
# Band Names: ['distance']
# Export task started for 56_vietnam_areas_shp!
# Width: 26995, Height: 25015
# Band Names: ['distance']
# Export task started for 57_cambodia_areas_shp!
# Width: 25227, Height: 27799
# Band Names: ['distance']
# Export task started for 58_cambodia_areas_shp!
# Width: 25274, Height: 25920
# Band Names: ['distance']
# Export task started for 59_cambodia_areas_shp!
# Width: 17114, Height: 17384
# Band Names: ['distance']
# Export task started for 5_cambodia_areas_shp!
# Width: 27146, Height: 25740
# Band Names: ['distance']
# Export task started for 60_cambodia_areas_shp!
# Width: 27190, Height: 28456
# Band Names: ['distance']
# Export task started for 61_cambodia_areas_shp!
# Width: 17114, Height: 17188
# Band Names: ['distance']
# Export task started for 6_cambodia_areas_shp!
# Width: 17114, Height: 17327
# Band Names: ['distance']
# Export task started for 7_cambodia_areas_shp!
# Width: 17115, Height: 17307
# Band Names: ['distance']
# Export task started for 8_cambodia_areas_shp!
# Width: 17113, Height: 17312
# Band Names: ['distance']
# Export task started for 9_cambodia_areas_shp!

# %% [markdown]
# # Single Download from GEE Asset

# %%
name = "pantanaw_02"
# cambodia_areas_10 = ee.FeatureCollection(f'projects/earthengine-legacy/assets/projects/servir-mekong/khProject/data/{name}');
# cambodia_areas_10 = ee.FeatureCollection(f'projects/myanmar-crops/assets/fieldBoundaries/Sailin428');
ft2download = ee.FeatureCollection(f'projects/myanmar-crops/assets/fieldBoundaries/pantanaw_02'); 
bounds_info = ft2download.geometry().bounds().getInfo()

# Extract the coordinates from the bounds_info
coordinates = bounds_info['coordinates'][0]

# Calculate xmin, xmax, ymin, ymax
longitudes = [point[0] for point in coordinates]
latitudes = [point[1] for point in coordinates]

xmin = min(longitudes)
xmax = max(longitudes)
ymin = min(latitudes)
ymax = max(latitudes)

# print(f'filename: {ft2download}')
print(f"xmin: {xmin}, xmax: {xmax}, ymin: {ymin}, ymax: {ymax}")
# Out:
# xmin: 95.46086784950023, xmax: 95.47876668331524, ymin: 16.930979297496407, ymax: 16.948989603803135

# %%
from getData import tms_to_geotiff
from PIL import Image
import numpy as np

bbox = [xmin,
        ymin,
        xmax,
        ymax ]

nr = 1
image = f"D:/SIG/Sam2_source/Crops/{name}.tif" 
satImg = tms_to_geotiff(output=image, bbox=bbox, zoom=19, source="Satellite", overwrite=True, return_image=True)
# Out:
# Downloaded image 001/784
# Downloaded image 002/784
# Downloaded image 003/784
# Downloaded image 004/784
# Downloaded image 005/784
# Downloaded image 006/784
# Downloaded image 007/784
# Downloaded image 008/784
# Downloaded image 009/784
# Downloaded image 010/784
# Downloaded image 011/784
# Downloaded image 012/784
# Downloaded image 013/784
# Downloaded image 014/784
# Downloaded image 015/784
# Downloaded image 016/784
# Downloaded image 017/784
# Downloaded image 018/784
# Downloaded image 019/784
# Downloaded image 020/784
# Downloaded image 021/784
# Downloaded image 022/784
# Downloaded image 023/784
# Downloaded image 024/784
# Downloaded image 025/784
# Downloaded image 026/784
# Downloaded image 027/784
# Downloaded image 028/784
# Downloaded image 029/784
# Downloaded image 030/784
# Downloaded image 031/784
# Downloaded image 032/784
# Downloaded image 033/784
# Downloaded image 034/784
# Downloaded image 035/784
# Downloaded image 036/784
# Downloaded image 037/784
# Downloaded image 038/784
# Downloaded image 039/784
# Downloaded image 040/784
# Downloaded image 041/784
# Downloaded image 042/784
# Downloaded image 043/784
# Downloaded image 044/784
# Downloaded image 045/784
# Downloaded image 046/784
# Downloaded image 047/784
# Downloaded image 048/784
# Downloaded image 049/784
# Downloaded image 050/784
# Downloaded image 051/784
# Downloaded image 052/784
# Downloaded image 053/784
# Downloaded image 054/784
# Downloaded image 055/784
# Downloaded image 056/784
# Downloaded image 057/784
# Downloaded image 058/784
# Downloaded image 059/784
# Downloaded image 060/784
# Downloaded image 061/784
# Downloaded image 062/784
# Downloaded image 063/784
# Downloaded image 064/784
# Downloaded image 065/784
# Downloaded image 066/784
# Downloaded image 067/784
# Downloaded image 068/784
# Downloaded image 069/784
# Downloaded image 070/784
# Downloaded image 071/784
# Downloaded image 072/784
# Downloaded image 073/784
# Downloaded image 074/784
# Downloaded image 075/784
# Downloaded image 076/784
# Downloaded image 077/784
# Downloaded image 078/784
# Downloaded image 079/784
# Downloaded image 080/784
# Downloaded image 081/784
# Downloaded image 082/784
# Downloaded image 083/784
# Downloaded image 084/784
# Downloaded image 085/784
# Downloaded image 086/784
# Downloaded image 087/784
# Downloaded image 088/784
# Downloaded image 089/784
# Downloaded image 090/784
# Downloaded image 091/784
# Downloaded image 092/784
# Downloaded image 093/784
# Downloaded image 094/784
# Downloaded image 095/784
# Downloaded image 096/784
# Downloaded image 097/784
# Downloaded image 098/784
# Downloaded image 099/784
# Downloaded image 100/784
# Downloaded image 101/784
# Downloaded image 102/784
# Downloaded image 103/784
# Downloaded image 104/784
# Downloaded image 105/784
# Downloaded image 106/784
# Downloaded image 107/784
# Downloaded image 108/784
# Downloaded image 109/784
# Downloaded image 110/784
# Downloaded image 111/784
# Downloaded image 112/784
# Downloaded image 113/784
# Downloaded image 114/784
# Downloaded image 115/784
# Downloaded image 116/784
# Downloaded image 117/784
# Downloaded image 118/784
# Downloaded image 119/784
# Downloaded image 120/784
# Downloaded image 121/784
# Downloaded image 122/784
# Downloaded image 123/784
# Downloaded image 124/784
# Downloaded image 125/784
# Downloaded image 126/784
# Downloaded image 127/784
# Downloaded image 128/784
# Downloaded image 129/784
# Downloaded image 130/784
# Downloaded image 131/784
# Downloaded image 132/784
# Downloaded image 133/784
# Downloaded image 134/784
# Downloaded image 135/784
# Downloaded image 136/784
# Downloaded image 137/784
# Downloaded image 138/784
# Downloaded image 139/784
# Downloaded image 140/784
# Downloaded image 141/784
# Downloaded image 142/784
# Downloaded image 143/784
# Downloaded image 144/784
# Downloaded image 145/784
# Downloaded image 146/784
# Downloaded image 147/784
# Downloaded image 148/784
# Downloaded image 149/784
# Downloaded image 150/784
# Downloaded image 151/784
# Downloaded image 152/784
# Downloaded image 153/784
# Downloaded image 154/784
# Downloaded image 155/784
# Downloaded image 156/784
# Downloaded image 157/784
# Downloaded image 158/784
# Downloaded image 159/784
# Downloaded image 160/784
# Downloaded image 161/784
# Downloaded image 162/784
# Downloaded image 163/784
# Downloaded image 164/784
# Downloaded image 165/784
# Downloaded image 166/784
# Downloaded image 167/784
# Downloaded image 168/784
# Downloaded image 169/784
# Downloaded image 170/784
# Downloaded image 171/784
# Downloaded image 172/784
# Downloaded image 173/784
# Downloaded image 174/784
# Downloaded image 175/784
# Downloaded image 176/784
# Downloaded image 177/784
# Downloaded image 178/784
# Downloaded image 179/784
# Downloaded image 180/784
# Downloaded image 181/784
# Downloaded image 182/784
# Downloaded image 183/784
# Downloaded image 184/784
# Downloaded image 185/784
# Downloaded image 186/784
# Downloaded image 187/784
# Downloaded image 188/784
# Downloaded image 189/784
# Downloaded image 190/784
# Downloaded image 191/784
# Downloaded image 192/784
# Downloaded image 193/784
# Downloaded image 194/784
# Downloaded image 195/784
# Downloaded image 196/784
# Downloaded image 197/784
# Downloaded image 198/784
# Downloaded image 199/784
# Downloaded image 200/784
# Downloaded image 201/784
# Downloaded image 202/784
# Downloaded image 203/784
# Downloaded image 204/784
# Downloaded image 205/784
# Downloaded image 206/784
# Downloaded image 207/784
# Downloaded image 208/784
# Downloaded image 209/784
# Downloaded image 210/784
# Downloaded image 211/784
# Downloaded image 212/784
# Downloaded image 213/784
# Downloaded image 214/784
# Downloaded image 215/784
# Downloaded image 216/784
# Downloaded image 217/784
# Downloaded image 218/784
# Downloaded image 219/784
# Downloaded image 220/784
# Downloaded image 221/784
# Downloaded image 222/784
# Downloaded image 223/784
# Downloaded image 224/784
# Downloaded image 225/784
# Downloaded image 226/784
# Downloaded image 227/784
# Downloaded image 228/784
# Downloaded image 229/784
# Downloaded image 230/784
# Downloaded image 231/784
# Downloaded image 232/784
# Downloaded image 233/784
# Downloaded image 234/784
# Downloaded image 235/784
# Downloaded image 236/784
# Downloaded image 237/784
# Downloaded image 238/784
# Downloaded image 239/784
# Downloaded image 240/784
# Downloaded image 241/784
# Downloaded image 242/784
# Downloaded image 243/784
# Downloaded image 244/784
# Downloaded image 245/784
# Downloaded image 246/784
# Downloaded image 247/784
# Downloaded image 248/784
# Downloaded image 249/784
# Downloaded image 250/784
# Downloaded image 251/784
# Downloaded image 252/784
# Downloaded image 253/784
# Downloaded image 254/784
# Downloaded image 255/784
# Downloaded image 256/784
# Downloaded image 257/784
# Downloaded image 258/784
# Downloaded image 259/784
# Downloaded image 260/784
# Downloaded image 261/784
# Downloaded image 262/784
# Downloaded image 263/784
# Downloaded image 264/784
# Downloaded image 265/784
# Downloaded image 266/784
# Downloaded image 267/784
# Downloaded image 268/784
# Downloaded image 269/784
# Downloaded image 270/784
# Downloaded image 271/784
# Downloaded image 272/784
# Downloaded image 273/784
# Downloaded image 274/784
# Downloaded image 275/784
# Downloaded image 276/784
# Downloaded image 277/784
# Downloaded image 278/784
# Downloaded image 279/784
# Downloaded image 280/784
# Downloaded image 281/784
# Downloaded image 282/784
# Downloaded image 283/784
# Downloaded image 284/784
# Downloaded image 285/784
# Downloaded image 286/784
# Downloaded image 287/784
# Downloaded image 288/784
# Downloaded image 289/784
# Downloaded image 290/784
# Downloaded image 291/784
# Downloaded image 292/784
# Downloaded image 293/784
# Downloaded image 294/784
# Downloaded image 295/784
# Downloaded image 296/784
# Downloaded image 297/784
# Downloaded image 298/784
# Downloaded image 299/784
# Downloaded image 300/784
# Downloaded image 301/784
# Downloaded image 302/784
# Downloaded image 303/784
# Downloaded image 304/784
# Downloaded image 305/784
# Downloaded image 306/784
# Downloaded image 307/784
# Downloaded image 308/784
# Downloaded image 309/784
# Downloaded image 310/784
# Downloaded image 311/784
# Downloaded image 312/784
# Downloaded image 313/784
# Downloaded image 314/784
# Downloaded image 315/784
# Downloaded image 316/784
# Downloaded image 317/784
# Downloaded image 318/784
# Downloaded image 319/784
# Downloaded image 320/784
# Downloaded image 321/784
# Downloaded image 322/784
# Downloaded image 323/784
# Downloaded image 324/784
# Downloaded image 325/784
# Downloaded image 326/784
# Downloaded image 327/784
# Downloaded image 328/784
# Downloaded image 329/784
# Downloaded image 330/784
# Downloaded image 331/784
# Downloaded image 332/784
# Downloaded image 333/784
# Downloaded image 334/784
# Downloaded image 335/784
# Downloaded image 336/784
# Downloaded image 337/784
# Downloaded image 338/784
# Downloaded image 339/784
# Downloaded image 340/784
# Downloaded image 341/784
# Downloaded image 342/784
# Downloaded image 343/784
# Downloaded image 344/784
# Downloaded image 345/784
# Downloaded image 346/784
# Downloaded image 347/784
# Downloaded image 348/784
# Downloaded image 349/784
# Downloaded image 350/784
# Downloaded image 351/784
# Downloaded image 352/784
# Downloaded image 353/784
# Downloaded image 354/784
# Downloaded image 355/784
# Downloaded image 356/784
# Downloaded image 357/784
# Downloaded image 358/784
# Downloaded image 359/784
# Downloaded image 360/784
# Downloaded image 361/784
# Downloaded image 362/784
# Downloaded image 363/784
# Downloaded image 364/784
# Downloaded image 365/784
# Downloaded image 366/784
# Downloaded image 367/784
# Downloaded image 368/784
# Downloaded image 369/784
# Downloaded image 370/784
# Downloaded image 371/784
# Downloaded image 372/784
# Downloaded image 373/784
# Downloaded image 374/784
# Downloaded image 375/784
# Downloaded image 376/784
# Downloaded image 377/784
# Downloaded image 378/784
# Downloaded image 379/784
# Downloaded image 380/784
# Downloaded image 381/784
# Downloaded image 382/784
# Downloaded image 383/784
# Downloaded image 384/784
# Downloaded image 385/784
# Downloaded image 386/784
# Downloaded image 387/784
# Downloaded image 388/784
# Downloaded image 389/784
# Downloaded image 390/784
# Downloaded image 391/784
# Downloaded image 392/784
# Downloaded image 393/784
# Downloaded image 394/784
# Downloaded image 395/784
# Downloaded image 396/784
# Downloaded image 397/784
# Downloaded image 398/784
# Downloaded image 399/784
# Downloaded image 400/784
# Downloaded image 401/784
# Downloaded image 402/784
# Downloaded image 403/784
# Downloaded image 404/784
# Downloaded image 405/784
# Downloaded image 406/784
# Downloaded image 407/784
# Downloaded image 408/784
# Downloaded image 409/784
# Downloaded image 410/784
# Downloaded image 411/784
# Downloaded image 412/784
# Downloaded image 413/784
# Downloaded image 414/784
# Downloaded image 415/784
# Downloaded image 416/784
# Downloaded image 417/784
# Downloaded image 418/784
# Downloaded image 419/784
# Downloaded image 420/784
# Downloaded image 421/784
# Downloaded image 422/784
# Downloaded image 423/784
# Downloaded image 424/784
# Downloaded image 425/784
# Downloaded image 426/784
# Downloaded image 427/784
# Downloaded image 428/784
# Downloaded image 429/784
# Downloaded image 430/784
# Downloaded image 431/784
# Downloaded image 432/784
# Downloaded image 433/784
# Downloaded image 434/784
# Downloaded image 435/784
# Downloaded image 436/784
# Downloaded image 437/784
# Downloaded image 438/784
# Downloaded image 439/784
# Downloaded image 440/784
# Downloaded image 441/784
# Downloaded image 442/784
# Downloaded image 443/784
# Downloaded image 444/784
# Downloaded image 445/784
# Downloaded image 446/784
# Downloaded image 447/784
# Downloaded image 448/784
# Downloaded image 449/784
# Downloaded image 450/784
# Downloaded image 451/784
# Downloaded image 452/784
# Downloaded image 453/784
# Downloaded image 454/784
# Downloaded image 455/784
# Downloaded image 456/784
# Downloaded image 457/784
# Downloaded image 458/784
# Downloaded image 459/784
# Downloaded image 460/784
# Downloaded image 461/784
# Downloaded image 462/784
# Downloaded image 463/784
# Downloaded image 464/784
# Downloaded image 465/784
# Downloaded image 466/784
# Downloaded image 467/784
# Downloaded image 468/784
# Downloaded image 469/784
# Downloaded image 470/784
# Downloaded image 471/784
# Downloaded image 472/784
# Downloaded image 473/784
# Downloaded image 474/784
# Downloaded image 475/784
# Downloaded image 476/784
# Downloaded image 477/784
# Downloaded image 478/784
# Downloaded image 479/784
# Downloaded image 480/784
# Downloaded image 481/784
# Downloaded image 482/784
# Downloaded image 483/784
# Downloaded image 484/784
# Downloaded image 485/784
# Downloaded image 486/784
# Downloaded image 487/784
# Downloaded image 488/784
# Downloaded image 489/784
# Downloaded image 490/784
# Downloaded image 491/784
# Downloaded image 492/784
# Downloaded image 493/784
# Downloaded image 494/784
# Downloaded image 495/784
# Downloaded image 496/784
# Downloaded image 497/784
# Downloaded image 498/784
# Downloaded image 499/784
# Downloaded image 500/784
# Downloaded image 501/784
# Downloaded image 502/784
# Downloaded image 503/784
# Downloaded image 504/784
# Downloaded image 505/784
# Downloaded image 506/784
# Downloaded image 507/784
# Downloaded image 508/784
# Downloaded image 509/784
# Downloaded image 510/784
# Downloaded image 511/784
# Downloaded image 512/784
# Downloaded image 513/784
# Downloaded image 514/784
# Downloaded image 515/784
# Downloaded image 516/784
# Downloaded image 517/784
# Downloaded image 518/784
# Downloaded image 519/784
# Downloaded image 520/784
# Downloaded image 521/784
# Downloaded image 522/784
# Downloaded image 523/784
# Downloaded image 524/784
# Downloaded image 525/784
# Downloaded image 526/784
# Downloaded image 527/784
# Downloaded image 528/784
# Downloaded image 529/784
# Downloaded image 530/784
# Downloaded image 531/784
# Downloaded image 532/784
# Downloaded image 533/784
# Downloaded image 534/784
# Downloaded image 535/784
# Downloaded image 536/784
# Downloaded image 537/784
# Downloaded image 538/784
# Downloaded image 539/784
# Downloaded image 540/784
# Downloaded image 541/784
# Downloaded image 542/784
# Downloaded image 543/784
# Downloaded image 544/784
# Downloaded image 545/784
# Downloaded image 546/784
# Downloaded image 547/784
# Downloaded image 548/784
# Downloaded image 549/784
# Downloaded image 550/784
# Downloaded image 551/784
# Downloaded image 552/784
# Downloaded image 553/784
# Downloaded image 554/784
# Downloaded image 555/784
# Downloaded image 556/784
# Downloaded image 557/784
# Downloaded image 558/784
# Downloaded image 559/784
# Downloaded image 560/784
# Downloaded image 561/784
# Downloaded image 562/784
# Downloaded image 563/784
# Downloaded image 564/784
# Downloaded image 565/784
# Downloaded image 566/784
# Downloaded image 567/784
# Downloaded image 568/784
# Downloaded image 569/784
# Downloaded image 570/784
# Downloaded image 571/784
# Downloaded image 572/784
# Downloaded image 573/784
# Downloaded image 574/784
# Downloaded image 575/784
# Downloaded image 576/784
# Downloaded image 577/784
# Downloaded image 578/784
# Downloaded image 579/784
# Downloaded image 580/784
# Downloaded image 581/784
# Downloaded image 582/784
# Downloaded image 583/784
# Downloaded image 584/784
# Downloaded image 585/784
# Downloaded image 586/784
# Downloaded image 587/784
# Downloaded image 588/784
# Downloaded image 589/784
# Downloaded image 590/784
# Downloaded image 591/784
# Downloaded image 592/784
# Downloaded image 593/784
# Downloaded image 594/784
# Downloaded image 595/784
# Downloaded image 596/784
# Downloaded image 597/784
# Downloaded image 598/784
# Downloaded image 599/784
# Downloaded image 600/784
# Downloaded image 601/784
# Downloaded image 602/784
# Downloaded image 603/784
# Downloaded image 604/784
# Downloaded image 605/784
# Downloaded image 606/784
# Downloaded image 607/784
# Downloaded image 608/784
# Downloaded image 609/784
# Downloaded image 610/784
# Downloaded image 611/784
# Downloaded image 612/784
# Downloaded image 613/784
# Downloaded image 614/784
# Downloaded image 615/784
# Downloaded image 616/784
# Downloaded image 617/784
# Downloaded image 618/784
# Downloaded image 619/784
# Downloaded image 620/784
# Downloaded image 621/784
# Downloaded image 622/784
# Downloaded image 623/784
# Downloaded image 624/784
# Downloaded image 625/784
# Downloaded image 626/784
# Downloaded image 627/784
# Downloaded image 628/784
# Downloaded image 629/784
# Downloaded image 630/784
# Downloaded image 631/784
# Downloaded image 632/784
# Downloaded image 633/784
# Downloaded image 634/784
# Downloaded image 635/784
# Downloaded image 636/784
# Downloaded image 637/784
# Downloaded image 638/784
# Downloaded image 639/784
# Downloaded image 640/784
# Downloaded image 641/784
# Downloaded image 642/784
# Downloaded image 643/784
# Downloaded image 644/784
# Downloaded image 645/784
# Downloaded image 646/784
# Downloaded image 647/784
# Downloaded image 648/784
# Downloaded image 649/784
# Downloaded image 650/784
# Downloaded image 651/784
# Downloaded image 652/784
# Downloaded image 653/784
# Downloaded image 654/784
# Downloaded image 655/784
# Downloaded image 656/784
# Downloaded image 657/784
# Downloaded image 658/784
# Downloaded image 659/784
# Downloaded image 660/784
# Downloaded image 661/784
# Downloaded image 662/784
# Downloaded image 663/784
# Downloaded image 664/784
# Downloaded image 665/784
# Downloaded image 666/784
# Downloaded image 667/784
# Downloaded image 668/784
# Downloaded image 669/784
# Downloaded image 670/784
# Downloaded image 671/784
# Downloaded image 672/784
# Downloaded image 673/784
# Downloaded image 674/784
# Downloaded image 675/784
# Downloaded image 676/784
# Downloaded image 677/784
# Downloaded image 678/784
# Downloaded image 679/784
# Downloaded image 680/784
# Downloaded image 681/784
# Downloaded image 682/784
# Downloaded image 683/784
# Downloaded image 684/784
# Downloaded image 685/784
# Downloaded image 686/784
# Downloaded image 687/784
# Downloaded image 688/784
# Downloaded image 689/784
# Downloaded image 690/784
# Downloaded image 691/784
# Downloaded image 692/784
# Downloaded image 693/784
# Downloaded image 694/784
# Downloaded image 695/784
# Downloaded image 696/784
# Downloaded image 697/784
# Downloaded image 698/784
# Downloaded image 699/784
# Downloaded image 700/784
# Downloaded image 701/784
# Downloaded image 702/784
# Downloaded image 703/784
# Downloaded image 704/784
# Downloaded image 705/784
# Downloaded image 706/784
# Downloaded image 707/784
# Downloaded image 708/784
# Downloaded image 709/784
# Downloaded image 710/784
# Downloaded image 711/784
# Downloaded image 712/784
# Downloaded image 713/784
# Downloaded image 714/784
# Downloaded image 715/784
# Downloaded image 716/784
# Downloaded image 717/784
# Downloaded image 718/784
# Downloaded image 719/784
# Downloaded image 720/784
# Downloaded image 721/784
# Downloaded image 722/784
# Downloaded image 723/784
# Downloaded image 724/784
# Downloaded image 725/784
# Downloaded image 726/784
# Downloaded image 727/784
# Downloaded image 728/784
# Downloaded image 729/784
# Downloaded image 730/784
# Downloaded image 731/784
# Downloaded image 732/784
# Downloaded image 733/784
# Downloaded image 734/784
# Downloaded image 735/784
# Downloaded image 736/784
# Downloaded image 737/784
# Downloaded image 738/784
# Downloaded image 739/784
# Downloaded image 740/784
# Downloaded image 741/784
# Downloaded image 742/784
# Downloaded image 743/784
# Downloaded image 744/784
# Downloaded image 745/784
# Downloaded image 746/784
# Downloaded image 747/784
# Downloaded image 748/784
# Downloaded image 749/784
# Downloaded image 750/784
# Downloaded image 751/784
# Downloaded image 752/784
# Downloaded image 753/784
# Downloaded image 754/784
# Downloaded image 755/784
# Downloaded image 756/784
# Downloaded image 757/784
# Downloaded image 758/784
# Downloaded image 759/784
# Downloaded image 760/784
# Downloaded image 761/784
# Downloaded image 762/784
# Downloaded image 763/784
# Downloaded image 764/784
# Downloaded image 765/784
# Downloaded image 766/784
# Downloaded image 767/784
# Downloaded image 768/784
# Downloaded image 769/784
# Downloaded image 770/784
# Downloaded image 771/784
# Downloaded image 772/784
# Downloaded image 773/784
# Downloaded image 774/784
# Downloaded image 775/784
# Downloaded image 776/784
# Downloaded image 777/784
# Downloaded image 778/784
# Downloaded image 779/784
# Downloaded image 780/784
# Downloaded image 781/784
# Downloaded image 782/784
# Downloaded image 783/784
# Downloaded image 784/784
# Saving GeoTIFF. Please wait...
# Image saved to D:/SIG/Sam2_source/Crops/pantanaw_02.tif

# %%
import rasterio
# with rasterio.open('D:/SIG/Sam2_soucre/Crops/source_Z19_2/Images/Sailin493_areas_shp.tif') as dataset:
with rasterio.open(image) as dataset:
    # Get the width (number of columns) and height (number of rows)
    width = dataset.width
    height = dataset.height

print(f"Width: {width}, Height: {height}")
# Out:
# Width: 6673, Height: 7019

# %%
#// Calculate normalized distance for each polygon separately
#def normalizedDistanceImages = polygons.map(function(feature) {
def normalizedDistanceImages(feature):
  #// Create a rasterized version of the polygon
  #//var rasterizedPolygon = ee.Image.constant(1).clip(feature.geometry())
  rasterizedPolygon = ee.Image.constant(0).clip(feature.geometry()).unmask(1,False);

  #// Calculate the distance from the polygon boundary
  distance = rasterizedPolygon.distance(kernel=ee.Kernel.euclidean(255), skipMasked=False).clip(feature.geometry()).rename("distance"); #// Adjust the distance as needed

  #// Get the max distance as an image by reducing over the polygon geometry
  maxDistanceImage = distance.reduceRegion(
    reducer= ee.Reducer.max(),
    geometry= feature.geometry(),
    scale= 0.5,
    maxPixels= 1e9
  ).get('distance');

  #// Normalize distance within the polygon by dividing by the max distance
  normalizedDistance = distance.divide(ee.Number(maxDistanceImage));

  #// Clip to the polygon and set a unique index for mosaicking
  return normalizedDistance.clip(feature.geometry()).set('system:index', ee.String(feature.get('id')));


#// Merge all normalized distances into a single image
normalizedDistanceImages = ft2download.map(normalizedDistanceImages)
finalNormalizedDistanceImage = ee.ImageCollection(normalizedDistanceImages).mosaic();
print(finalNormalizedDistanceImage.bandNames().getInfo())
# Out:
# ['distance']

# %%
# Use the width and height in the dimensions parameter
dimensions = f"{width}x{height}"
# dimensions
# Define export parameters
export_task = ee.batch.Export.image.toDrive(
    image=finalNormalizedDistanceImage,
    description="Export_Normalized_Distance_To_Drive",
    folder="FieldZ19",  # Specify Google Drive folder
    fileNamePrefix=f"{name}_fields",  # File name prefix
    dimensions=dimensions,  # Set dimensions using width and height
    region=ft2download.geometry().bounds(),  # Define the region to export
    scale=None,  # Set scale to None since dimensions are specified
    crs="EPSG:4326",  # Coordinate Reference System
    maxPixels=1e12
)

# Start the export task
export_task.start()
print("Export task started!")
# Out:
# Export task started!
