# %% [markdown]
# # SET UP

# %%
'''
installation for cuda toolkit 11.7 (anacoda environtment)

pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
python -c "import torch; print(torch.cuda.is_available(), torch.version.cuda)"

'''

# %%
# pip install ultralytics

# %%
import ultralytics
ultralytics.checks()

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("CUDA Version:", torch.version.cuda)
print("Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU detected")

# %% [markdown]
# # Download YOLOv10 Pre-trained Weights

# %%
# Download YOLOv10 Pretrained Weights
import os
import requests

# Define the target directory
target_dir = "."

# Create the directory if it doesn't exist
os.makedirs(target_dir, exist_ok=True)

# List of YOLOv10 weights to download
weights_urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt",
]

# Download each file
for url in weights_urls:
    file_name = os.path.join(target_dir, os.path.basename(url))
    if not os.path.exists(file_name):  # Skip if file already exists
        print(f"Downloading {url}...")
        response = requests.get(url, stream=True)
        if response.status_code == 200:
            with open(file_name, 'wb') as file:
                file.write(response.content)
            print(f"Saved to {file_name}")
        else:
            print(f"Failed to download {url}")
    else:
        print(f"File already exists: {file_name}")

# %% [markdown]
# # TRAINING

# %%
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Disable GPU

# %%
from ultralytics import YOLO

# %%
# from ultralytics import YOLO
# Load a pre-trained YOLO model
model = YOLO('/Users/weraphongsuaruang/YoloSam_v0/YoloSam_v0_1/Yolo_Pretrain/yolov10m.pt')  
# Train the model
model.train(
    data='/Users/weraphongsuaruang/YoloSam_v0/01_Yolo_Training/data.yaml',  # Path to your dataset config
    epochs=10,                # Number of epochs
    imgsz=640,                 # Image size for training
    batch=8,                  # Batch size
    lr0=0.01,
    device="cpu",                   # Use GPU (0), or "cpu" for CPU
    project='/Users/weraphongsuaruang/YoloSam_v0/training_results',  
    name='train_medium_exp2'
)

# %%
from IPython.display import Image
from ultralytics import YOLO

# %%
Image(filename='/Users/weraphongsuaruang/YoloSam_v0/training_results/train_medium_exp22/confusion_matrix_normalized.png', width=600)

# %%
Image(filename='/Users/weraphongsuaruang/YoloSam_v0/training_results/train_medium_exp22/results.png', width=600)

# %% [markdown]
# # PREDICTION

# %%
from ultralytics import YOLO
# Load the best-performing model
model = YOLO('/Users/weraphongsuaruang/YoloSam_v0/training_results/train_medium_exp22/weights/best.pt')
# Use the model for predictions
results = model.predict(
    source= '/Users/weraphongsuaruang/Airbus_Combodia/00_crops',
    conf=0.25,
    save=True,  # Enable saving results
    imgsz=640,
    project='/Users/weraphongsuaruang/YoloSam_v0/predict',  # Custom directory
    name='field_detection_medium'  # Subdirectory name
)
